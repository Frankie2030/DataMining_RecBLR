# %% [markdown]
# # Import libraries (~10-30 minutes)

# %%
# !pip install "torch>=1.12,<2.6" "triton>=2.2" recbole "causal-conv1d>=1.2.0" einops "numpy<2" gdown
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 123.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.23.0+cu129 requires torch==2.8.0, but you have torch 2.5.1 which is incompatible.
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Download dataset

# %%
import gdown
gdown.download_folder("https://drive.google.com/drive/folders/1bwv9Ds3Y2IgkkT4lc5UKCC_ttSIWF2Xt?usp=sharing")
# Out:
# Retrieving folder contents
# Retrieving folder 1CEjTybniOij0XZAkCltJyGAl0y_481rD configs
# Processing file 1fB02X_k7R0vWzCZbRb_R6T6j8bYxNEuy config_amazon_beauty.yaml
# Processing file 1dsf27Au2eOc9b1qmdhCQ2RANx4CmU6HG config_ml_1m.yaml
# Processing file 1zdcuwlmR1uSJUS0VCJFjColVdCKwm2GO config_yelp.yaml
# Processing file 1SKA2iQ2wKVT_VXOOpaLhOrl8A2LuYP_4 amazon-beauty.inter
# Processing file 1plQret_fPDE0jngUW5v879nFA2fXRJUX ml-1m.inter
# Processing file 1y69ailq7tp-5VBtAAxMb6RVM8kJ6ZJFC parallel_scan.py
# Processing file 1O7KpM0b_HC9YLxTD1mbFFAXW3CnTemx9 plot_utils.py
# Processing file 1pBLGZmhFIWPAelkOy-RYwp3qe49pPuTU README.md
# Processing file 1u3IbWfulsl0tNoSFrLxzcKTSwzmZfoLh RecBLR.py
# Processing file 1LbcPh_f77RsQgnM42MzZf5TltgTgawrb run.py
# Processing file 1HaQUQzL04L1J_zVe6_mBKEaTchjyUzwP trim.py
# Processing file 1FlvHrhjTqtgA3AwQIyBZtoFyaZT9z2oS yelp.inter
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# ...

# %% [markdown]
# # Guide
# - model=R -> RecBLR
# - model=B -> BERT4Rec
# - config=B -> amazon-beauty
# - config=M -> ml-1m
# - config=Y -> yelp (1/8 latest interactions)
#
# **Here the configuration files only run for 10 epochs. Please change to 300 epochs (early_stopping=10) because that is the default parameters on the author's repository.**

# %%
# !cd /root/RecBLR && python run.py --model R --config B
# Out:
# command line args [--model R --config B] will not be used in RecBole
# 07 Nov 17:08    INFO  ['run.py', '--model', 'R', '--config', 'B']
# 07 Nov 17:08    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/amazon-beauty
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# ...

# %%
import torch
import gc

# Collect Python garbage to release references to tensors
gc.collect()

# Empty the PyTorch CUDA memory cache
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("CUDA cache cleared.")
# Out:
# CUDA cache cleared.

# %%
# !cd /root/RecBLR && python run.py --model B --config B
# Out:
# command line args [--model B --config B] will not be used in RecBole
# 07 Nov 16:58    INFO  ['run.py', '--model', 'B', '--config', 'B']
# 07 Nov 16:58    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = dataset/amazon-beauty
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'none', 'sample_num': 'none', 'alpha': 'none', 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'LS': 'valid_and_test'}, 'order': 'TO', 'group_by': 'user', 'mode': {'valid': 'full', 'test': 'full'}}
# ...

# %%
# !cd /root/RecBLR && python run.py --model R --config M

# %%
# !cd /root/RecBLR && python run.py --model B --config M

# %%
# !cd /root/RecBLR && python run.py --model R --config Y

# %%
# !cd /root/RecBLR && python run.py --model B --config Y
